# %% [markdown]
# Sigamos con más visualizaciones. En este caso trabajaremos con el csv que generamos en el ejercicio de pair programming de Pandas V, ese en el que habíamos unido distintos csv en uno. Al final nos habíamos quedado con los siguientes conjuntos de datos
# El fichero de la unión de todos los conjuntos de datos de los distintos años
# El fichero con la unión de los datos de puestos y empleados.
# El fichero de los agentes.
# 📌 NOTA Os dejamos abajo los ficheros por si no os hubiera dado tiempo a tenerlos preparados
# El objetivo de hoy, mejorar algunas de las gráficas que hicimos en el ejericio de pair programming de ayer y crear algunas nuevas aprovechando que tenemos algunas columnas nuevas en dataframe
# Las preguntas que tendréis que contestar son:

# %% [markdown]
# 1. Ayer creamos un par de gráficas para los tickets de la categoría "Software" y "Hardware", donde visualizamos el número de clientes que teníamos en cada grupo de satisfacción. Hoy tendréis que hacer dos gráficas con subplots:
#     - En la primera debéis mostrar la cantidad de tickets en función del tipo (si es Problema o Solicitud), cada subplot corresponderá a cada una de las categorías. Debéis:
#         - Poner nombre a los ejes de cada uno de los subplots
#         - Poner un títulos a cada uno de los subplots
#         - Poner el color de las líneas en negro.
#         - Establecer el tamaño de la gráfica a 15 x 5
#         - Ponerle marcadores a las gráficas
#         - No incluir leyenda
#
#     -En la segunda debéis mostrar el número de tickets en función de la satisfacción.
#
#         - De nuevo tendréis que ponerle nombre a los ejes y título a cada gráfica.
#         - En este caso el subplot deberá tener dos filas y una columna
#         - No incluir leyenda
#         - Cambiar el color de las barras

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datos/2016_edit.csv")

# %%
df_soft = df[(df["categoría"]  == "Software")]
df_hard = df[(df["categoría"]  == "Hardware")]

# %%
df_tipo_soft = df_soft["tipo"].value_counts().reset_index()
df_tipo_hard = df_hard["tipo"].value_counts().reset_index()

# %%
df_sat_soft = df_soft["satisfacción"].value_counts().reset_index()
df_sat_hard = df_hard["satisfacción"].value_counts().reset_index()

# %%
# añadimos el parámetro figsize para establecer el tamaño de la gráfica
fig,ax = plt.subplots(1,2, figsize =( 15,5))

ax[0].bar(df_tipo_soft["index"], df_tipo_soft["tipo"], edgecolor = "black")
ax[0].set_xlabel("Tipos de incidencias")
ax[0].set_ylabel("Número de tickets")
ax[0].set_title("Software")


ax[1].bar(df_tipo_hard["index"], df_tipo_hard["tipo"], edgecolor = "black", color = "lime")
ax[1].set_xlabel("Tipos de incidencias")
ax[1].set_ylabel("Número de tickets")
ax[1].set_title("Hardware")
plt.show()

# %%
# añadimos el parámetro figsize para establecer el tamaño de la gráfica
fig,ax = plt.subplots(2,1, figsize =(6,10))

ax[0].bar(df_sat_soft["index"], df_sat_soft["satisfacción"], edgecolor = "black", color = "maroon")
ax[0].set_xlabel("Nivel de satisfacción")
ax[0].set_ylabel("Número de tickets")
ax[0].set_title("Software")


ax[1].bar(df_sat_hard["index"], df_sat_hard["satisfacción"], edgecolor = "black", color = "lime")
ax[1].set_xlabel("Nivel de satisfacción")
ax[1].set_ylabel("Número de tickets")
ax[1].set_title("Hardware")
plt.show()

# %% [markdown]
# Cread un subplot con dos gráficas, dónde en la primera tengamos el número de empleados por departamento y en la otra por tipo de puesto. Debéis:
#
#     - Poner leyenda a la gráfica
#     - Cada línea debe ir en un color
#     - Ponerle nombre a los ejes y a la gráfica.
#     - Poner marcadores a las lineas

# %%
df_empleo = pd.read_csv("datos/empleo.csv")

# %%
df_empleo.head(10)
# Out:
#    Unnamed: 0 turno  id_empleado    apellido    nombre id_puesto  \
# 0           0     A            6       VILLA     JESUS  50-32200
# 1           1   NaN           60        DIAZ  PATRICIA  50-32200
# 2           2     B            2      DUARTE   ANTONIO  50-32200
# 3           3   NaN           24  VILLANUEVA     JESUS  50-32200
# 4           4   NaN           98    GALLEGOS  PATRICIA  50-32200
# 5           5   NaN         1409   CONTRERAS   ANTONIO  50-32200
# 6           6   NaN           10      MENDEZ   RICARDO  15-24100
# 7           7   NaN           27       DURAN   DESSENS  15-24100
# 8           8   NaN           63      Pareja  Fernando  15-24100
# 9           9   NaN           99      GARCIA     DIANA  15-24100
#
#                              email                    puesto  \
# 0        jesus.villa@tractchun.com   Comprador de Materiales
# 1      patricia.diaz@tractchun.com   Comprador de Materiales
# 2     antonio.duarte@tractchun.com   Comprador de Materiales
# ...

# %%
df_departamento = df_empleo["departamento"].value_counts().reset_index()
df_departamento
# Out:
#                                           index  departamento
# 0                                    PRODUCCION           475
# 1                         INGENIERIA DE CALIDAD           395
# 2                                 MANTENIMIENTO           258
# 3                     INGENIERIA DE MANUFACTURA           228
# 4                   SISTEMAS, TRAFICO Y ADUANAS           160
# 5                         CONTROL DE PRODUCCION           127
# 6                                    MATERIALES           125
# 7                              Recursos Humanos           117
# 8   AUDITORIA INTERNA, CALIBRACION Y METROLOGIA            70
# 9                                  CONTABILIDAD            25
# 10                                     PERSONAL            20

# %%
df_puesto = df_empleo["tipo_puesto"].value_counts().reset_index()
df_puesto
# Out:
#             index  tipo_puesto
# 0   Mandos Medios         1060
# 1       Operativo          577
# 2  Administrativo          321
# 3        Gerencia           42

# %%
# añadimos el parámetro figsize para establecer el tamaño de la gráfica
fig,ax = plt.subplots(2,1, figsize =(15,18))

ax[0].plot(df_departamento["index"], df_departamento["departamento"], marker = "v")
ax[0].set_xlabel("Departamentos")
ax[0].tick_params(rotation = 45)
ax[0].set_ylabel("Número de empleados")
ax[0].set_title("Departamento")


ax[1].plot(df_puesto["index"], df_puesto["tipo_puesto"], color = "lime", marker = "D")
ax[1].set_xlabel("Tipos de puestos")
ax[1].set_ylabel("Número de empleados")
ax[1].set_title("Tipo de puesto")
plt.show()
