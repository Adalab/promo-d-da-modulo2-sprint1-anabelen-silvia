# %% [markdown]
# # Pair Programming Visualización I
#
# Es el momento de ponernos manos a la obra con la visualización de datos. En este primer ejercicio de pair programming trabajaremos con los csv que generamos en el ejercicio de pair programming de Pandas III, ese en el que habíamos eliminado algunas columnas de nuestro csv.
# Hoy realizaremos una serie de gráficas usando la librería de matplotlib para familiarizarnos un poco con los datos.
# 📌 Para poder solucionar los ejercicios de hoy no solo tendremos que visualizar, también tendremos que usar métodos que hemos aprendido en lecciones anteriores de Pandas como por ejemplo value_counts(), isnull, describe, etc.
# Tendréis que realizar gráficas para contestar a las siguientes preguntas:
#
#     1. ¿Cuántos tickets tenemos de cada tipo?

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datos/2016_edit.csv")

# %%
df.sample(10)
# Out:
#                id_ticket       fecha  id_empleado  id_agente      categoría  \
# 2025   GHLTSR-1542612604  2016-08-30       1000.0       36.0        Sistema
# 8472   SDLTSR-7542705016  2016-12-01        211.0       40.0        Sistema
# 5921   KHLTNT-5042495959  2016-05-05       1675.0       39.0  Acceso&%Login
# 11495  THLTER-0042401047  2016-02-01       1404.0       30.0       Software
# 10664  TDLESR-0542530825  2016-06-09       1822.0       28.0        Sistema
# 2513   GHRTNT-4042730476  2016-12-26       1447.0       14.0  Acceso&%Login
# 8130   SDLTER-8942373859  2016-01-04       1865.0       28.0       Software
# 10462  SWLTSR-5742448364  2016-03-19       1706.0       33.0        Sistema
# 558    GDLTNR-3042714553  2016-12-10        145.0       45.0  Acceso&%Login
# 12484  TMLTNT-9042725843  2016-12-21        824.0       18.0  Acceso&%Login
#
#             tipo   severidad        prioridad  días_resolución  satisfacción
# ...

# %%
df_tipo = df["tipo"].value_counts().reset_index()
df_tipo
# Out:
#        index  tipo
# 0  Solicitud  9756
# 1   Problema  3294

# %%
plt.figure()
plt.bar(df_tipo["index"], df_tipo["tipo"])
plt.show()

# %% [markdown]
#     2.  Filtrar los datos para quedarnos solo con los datos de la categoría "Software".

# %%
df.sample(10)
# Out:
#               id_ticket       fecha  id_empleado  id_agente      categoría  \
# 4688  KDLTSR-4442673008  2016-10-30       1010.0       50.0        Sistema
# 4078  KDLTER-1642388448  2016-01-19       1254.0        4.0       Hardware
# 8582  SDRTNR-2042682321  2016-11-08       1272.0       13.0  Acceso&%Login
# 3331  GWLTER-5542447146  2016-03-18        334.0       41.0       Hardware
# 1833  GHLTNR-6042526098  2016-06-05        819.0       10.0  Acceso&%Login
# 3729  GWRESR-6242429786  2016-02-29       1568.0       47.0        Sistema
# 7134  KMRESR-7142415720  2016-02-15        532.0       37.0        Sistema
# 8325  SDLTNT-4042446032  2016-03-17       1163.0       50.0  Acceso&%Login
# 7780  KWRENR-8042612772  2016-08-30        437.0       47.0  Acceso&%Login
# 2761  GMLTER-7442497700  2016-05-07        840.0       17.0       Software
#
#            tipo   severidad        prioridad  días_resolución  satisfacción
# ...

# %%
df_soft = df[(df["categoría"]  == "Software")]
df_soft
# Out:
#                id_ticket       fecha  id_empleado  id_agente categoría  \
# 4      GDLEER-0042524120  2016-06-03       1842.0       31.0  Software
# 5      GDLEER-0142608095  2016-08-26         59.0       20.0  Software
# 6      GDLEER-0242564650  2016-07-13       1175.0       36.0  Software
# 7      GDLEER-0542574815  2016-07-23        561.0       18.0  Software
# 8      GDLEER-0842457219  2016-03-28         71.0       12.0  Software
# ...                  ...         ...          ...        ...       ...
# 13020  TWREER-3542682716  2016-11-08        411.0       37.0  Software
# 13022  TWREER-4142552705  2016-07-01       1680.0       27.0  Software
# 13034  TWRTER-2042528927  2016-06-07        462.0       19.0  Software
# 13036  TWRTER-8742418826  2016-02-18        942.0       28.0  Software
# 13037  TWRTER-9542402645  2016-02-02        334.0       26.0  Software
#
#             tipo   severidad        prioridad  días_resolución  satisfacción
# ...

# %%
df_hard = df[(df["categoría"]  == "Hardware")]
df_hard
# Out:
#                id_ticket       fecha  id_empleado  id_agente categoría  \
# 15     GDLEER-2342731423  2016-12-27        422.0       24.0  Hardware
# 18     GDLEER-3042628638  2016-09-15       1863.0       46.0  Hardware
# 25     GDLEER-3542665966  2016-10-22       1996.0       29.0  Hardware
# 27     GDLEER-3742656857  2016-10-13       1025.0       18.0  Hardware
# 28     GDLEER-4042683896  2016-11-09       1469.0       38.0  Hardware
# ...                  ...         ...          ...        ...       ...
# 12799  TWLTER-9942724654  2016-12-20       1245.0       16.0  Hardware
# 12802  TWLTET-8342499857  2016-05-09       1045.0       28.0  Hardware
# 13021  TWREER-4142462018  2016-04-02        111.0       30.0  Hardware
# 13035  TWRTER-5042710887  2016-12-06       1098.0       38.0  Hardware
# 13038  TWRTER-9642514691  2016-05-24        909.0       16.0  Hardware
#
#             tipo   severidad        prioridad  días_resolución  satisfacción
# ...

# %%
df_tipo_soft = df_soft["tipo"].value_counts().reset_index()
df_tipo_soft
# Out:
#        index  tipo
# 0  Solicitud  1948
# 1   Problema   664

# %%
df_tipo_hard = df_hard["tipo"].value_counts().reset_index()
df_tipo_hard
# Out:
#        index  tipo
# 0  Solicitud   956
# 1   Problema   315

# %% [markdown]
#         2.1. Dentro del conjunto de datos filtrado que acabamos de generar, realiza la mejor visualización para mostrar cuantos tickets tenemos de cada tipo que tenemos (Problema o Solicitud).

# %%
plt.figure()
plt.barh(df_tipo_soft["index"], df_tipo_soft["tipo"])
plt.show()

# %%
plt.figure()
plt.barh(df_tipo_hard["index"], df_tipo_hard["tipo"])
plt.show()

# %% [markdown]
# Comparando las gráficas vemos que tenemos aproximadamente el doble de incidencias de software que de hardware. De cada 4 incidencias aproximadamente 1 es de tipo problema y 3 de tipo solicitud.

# %% [markdown]
#         2.2. Usando el mismo conjunto de datos filtrado, ¿existe alguna relación entre la satisfacción y los días de resolución?. Poned los nombres de los ejes, siendo el eje x los "días de resolución" y el eje y la "satisfacción".

# %%
df_soft
# Out:
#                id_ticket       fecha  id_empleado  id_agente categoría  \
# 4      GDLEER-0042524120  2016-06-03       1842.0       31.0  Software
# 5      GDLEER-0142608095  2016-08-26         59.0       20.0  Software
# 6      GDLEER-0242564650  2016-07-13       1175.0       36.0  Software
# 7      GDLEER-0542574815  2016-07-23        561.0       18.0  Software
# 8      GDLEER-0842457219  2016-03-28         71.0       12.0  Software
# ...                  ...         ...          ...        ...       ...
# 13020  TWREER-3542682716  2016-11-08        411.0       37.0  Software
# 13022  TWREER-4142552705  2016-07-01       1680.0       27.0  Software
# 13034  TWRTER-2042528927  2016-06-07        462.0       19.0  Software
# 13036  TWRTER-8742418826  2016-02-18        942.0       28.0  Software
# 13037  TWRTER-9542402645  2016-02-02        334.0       26.0  Software
#
#             tipo   severidad        prioridad  días_resolución  satisfacción
# ...

# %%
# iniciamos nuestra figura
plt.figure()

# usamos el métdp scatter para hacer este tipo de gráfica donde especificamos lo que queremos en cada eje
# además vamos a añadir un parámetro que ya aprendimos en esta lección, el parámetro color que servía para cambiar el color de los puntos en este caso
plt.scatter(df_soft["días_resolución"],df_soft["satisfacción"])

# establecemos el nombre del eje x
plt.xlabel("días_resolución")

# establecemos el nombre del eje y
plt.ylabel("satisfacción")

# mostramos la gráfica
plt.show()

# %%
# iniciamos nuestra figura
plt.figure()

# usamos el métdp scatter para hacer este tipo de gráfica donde especificamos lo que queremos en cada eje
# además vamos a añadir un parámetro que ya aprendimos en esta lección, el parámetro color que servía para cambiar el color de los puntos en este caso
plt.scatter(df_hard["días_resolución"],df_hard["satisfacción"])

# establecemos el nombre del eje x
plt.xlabel("días_resolución")

# establecemos el nombre del eje y
plt.ylabel("satisfacción")

# mostramos la gráfica
plt.show()

# %% [markdown]
# Aunque tengamos dos variables numéricas, este tipo de diagrama no nos sirve ya que tendríamos que tratar la columna de satisfacción como categórica.

# %% [markdown]
#         2.3. Usando el mismo conjunto de datos filtrado, ¿cuál es la frecuencia de cada una de las satisfacciones que tenemos en el conjunto de datos?

# %%
# establecemos el marco de nuestra gráfica
plt.figure()

# utilizamos el método hist para hacer el histograma
plt.hist(x = df_soft["días_resolución"], facecolor  = 'red', edgecolor = "black" )

# mostramos la gráfica
plt.show()

# %%
# establecemos el marco de nuestra gráfica
plt.figure()

# utilizamos el método hist para hacer el histograma
plt.hist(x = df_hard["días_resolución"], facecolor  = 'red', edgecolor = "black" )

# mostramos la gráfica
plt.show()

# %% [markdown]
# Los días de resolución para software son considerablemente menores que para hardware.

# %%
# establecemos el marco de nuestra gráfica
plt.figure()

# utilizamos el método hist para hacer el histograma
plt.hist(x = df_soft["satisfacción"], facecolor  = 'red', edgecolor = "black" )

# mostramos la gráfica
plt.show()

# %%
# establecemos el marco de nuestra gráfica
plt.figure()

# utilizamos el método hist para hacer el histograma
plt.hist(x = df_hard["satisfacción"], facecolor  = 'red', edgecolor = "black" )

# mostramos la gráfica
plt.show()

# %% [markdown]
# En ambas categorías la mayoría de clientes parecen estar satisfechos.

# %% [markdown]
#     3. En el ejercicio anterior hemos filtrado por "Software", realizar los mismos ejercicios que en el ejercicio 3, solo que en este caso filtrar por "Hardware"
#
# Como ya hemos dicho en algunas ocasiones, somo analistas de datos y no debemos conformarnos solo con escribir el código y que nos devuelva una gráfica. Una vez que hayáis terminado de hacer las gráficas, interpretad los resultados obtenidos de las gráficas creadas en el ejercicio 3 y 4. El objetivo, hacer una comparación entre la categoría "Software" y "Hardware", por ejemplo, ¿están los clientes que tienen problemas de la categoría "Software" más satisfechos que los clientes de la categoría "Hardware".

# %% [markdown]
# Los ejercicios de hardware estan hechos a continuación de los de software para poder compararlos con más claridad.
