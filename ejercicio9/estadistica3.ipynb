# %% [markdown]
# Pair Programming Estadística III
# Vamos ahora a tomar de nuevo el conjunto de datos con el que estuvimos trabajando en los últimos días y vamos a continuar con el análisis de las estadísitcas de los contenidos del conjunto de datos.
# Para todas los ejercicios de pair programming de Estadística I, II y III usaremos el dataframe que se tome para el desarrollo de este ejercicio de pair programming.
# Se ruega a la hora de realizar la entrega que incluyais el conjunto de datos que hayais decidido emplear para estos ejercicios.
# Objetivos
# Los objetivos de hoy son:
#
#     1. Extraer los siguentes estadísiticos del conjunto de datos para varias de las varibles disponibles:
#         1.1. Tabla de contingencia

# %%
import pandas as pd

# %%
df = pd.read_csv("avocado.csv", index_col = 0)

# %%
df.sample(5)
# Out:
#           Date  AveragePrice  Total Volume       4046        4225      4770  \
# 42  2015-03-08          1.48       9468.77    8439.16      375.38      0.00
# 16  2015-09-06          1.04     301641.21   56439.41    83271.26  77352.73
# 10  2015-10-18          0.97    1856337.85   23873.63  1598365.27   1173.01
# 11  2016-10-09          0.91      27051.50     678.11     8511.22      0.00
# 19  2015-08-16          1.59     618237.58  145519.47   364968.69  27530.50
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 42      654.23      654.23        0.00         0.00       organic  2015
# 16    84577.81    83519.16     1058.65         0.00  conventional  2015
# 10   232925.94   181854.71    51069.15         2.08  conventional  2015
# 11    17862.17     1015.23    16846.94         0.00       organic  2016
# 19    80218.92    79372.32      846.60         0.00  conventional  2015
#
#                region
# 42           SanDiego
# 16  RaleighGreensboro
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18249 entries, 0 to 11
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.9+ MB

# %%
df["type"].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
df["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df["type"].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
df["region"].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %%
df_crosstab = pd.crosstab(df['region'], 
                          df['type'], margins= True) 
df_crosstab
# Out:
# type                 conventional  organic    All
# region
# Albany                        169      169    338
# Atlanta                       169      169    338
# BaltimoreWashington           169      169    338
# Boise                         169      169    338
# Boston                        169      169    338
# BuffaloRochester              169      169    338
# California                    169      169    338
# Charlotte                     169      169    338
# Chicago                       169      169    338
# CincinnatiDayton              169      169    338
# Columbus                      169      169    338
# DallasFtWorth                 169      169    338
# Denver                        169      169    338
# Detroit                       169      169    338
# GrandRapids                   169      169    338
# GreatLakes                    169      169    338
# HarrisburgScranton            169      169    338
# HartfordSpringfield           169      169    338
# ...

# %%
df_crosstab = pd.crosstab(df['year'], 
                          df['type'], margins= True) 
df_crosstab
# Out:
# type  conventional  organic    All
# year
# 2015          2808     2807   5615
# 2016          2808     2808   5616
# 2017          2862     2860   5722
# 2018           648      648   1296
# All           9126     9123  18249

# %% [markdown]
#         1.2. Coeficiente de correlación de las variables numéricas del dataset.

# %%
matriz_correlacion = df.corr()
matriz_correlacion
# Out:
# /tmp/ipykernel_6049/2926037190.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz_correlacion = df.corr()
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# establecemos el tamaño de la gráfica
plt.figure(figsize = (6,6))

# creamos la gráfica
sns.heatmap(df.corr(), # lo que queremos visualizar
            cmap = "mako", # color del gráfico
            annot = True, # para que nos aparezcan los valores de la correlacion
            vmin = -1, # establecemos el valor mínimo de la escala de color
            vmax = 1 # establecemos el valor máximo de la escala de color
);
# Out:
# /tmp/ipykernel_6049/1204451413.py:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), # lo que queremos visualizar

# %% [markdown]
#         1.3. Sesgos de alguna de las variables numéricas del dataset.

# %%
sns.displot(df["AveragePrice"], # sobre que columna queremos hacer la gráfica
            color = "green", # que color le queremos poner a la gráfica
            kde = True)

# %%
from scipy.stats import skew

# %%
skewness = skew(df['AveragePrice'])
print(f"El valor del sesgo para la variable price es: {skewness}")
# Out:
# El valor del sesgo para la variable price es: 0.5802550380696565

# %%
skewness = skew(df['Total Volume'])
print(f"El valor del sesgo para la variable Total Volume es: {skewness}")
# Out:
# El valor del sesgo para la variable Total Volume es: 9.006947063504116

# %%
sns.displot(df["Total Volume"], # sobre que columna queremos hacer la gráfica
            color = "blue", # que color le queremos poner a la gráfica
            kde = True)

plt.ylim(0, 1000)
# Out:
# (0.0, 1000.0)

# %%
sns.displot(df["Total Volume"], # sobre que columna queremos hacer la gráfica
            color = "blue", # que color le queremos poner a la gráfica
            kde = True)

plt.ylim(0, 1500)
plt.xlim(0, 1000000)
# Out:
# (0.0, 1000000.0)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
#         1.4. Intervalo de confianza de algunas de las variables numéricas del dataset

# %%
import numpy as np

# %%
import scipy.stats as st

# Queremos realizar el calculo de confianza para la media del precio de los cigarrillos
datos = df['AveragePrice']

# Utilizamos Scipy para calcular el intervalo de confianza del 95% de la media de los datos.
# Dicho intervalo nos indica donde está la media de los valores de longitud de los sépalos con un 95 de probabilidad.
print(st.t.interval(alpha=0.95, df=len(datos)-1, loc=np.mean(datos), scale=st.sem(datos)))

# Lo comparamos con la media obtenido de los datos disponibles hasta el momento
print(np.mean(datos))
# Out:
# (1.4001357081621193, 1.4118211113896368)
# 1.405978409775878
# /tmp/ipykernel_6049/1387847767.py:8: DeprecationWarning: Use of keyword argument 'alpha' for method 'interval' is deprecated and wil be removed in SciPy 1.11.0. Use first positional argument or keyword argument 'confidence' instead.
#   print(st.t.interval(alpha=0.95, df=len(datos)-1, loc=np.mean(datos), scale=st.sem(datos)))

# %%
import scipy.stats as st

# Queremos realizar el calculo de confianza para la media del precio de los cigarrillos
datos = df['Total Volume']

# Utilizamos Scipy para calcular el intervalo de confianza del 95% de la media de los datos.
# Dicho intervalo nos indica donde está la media de los valores de longitud de los sépalos con un 95 de probabilidad.
print(st.t.interval(alpha=0.90, df=len(datos)-1, loc=np.mean(datos), scale=st.sem(datos)))

# Lo comparamos con la media obtenido de los datos disponibles hasta el momento
print(np.mean(datos))
# Out:
# (808591.2114976329, 892696.8145202313)
# 850644.0130089321
# /tmp/ipykernel_6049/236717305.py:8: DeprecationWarning: Use of keyword argument 'alpha' for method 'interval' is deprecated and wil be removed in SciPy 1.11.0. Use first positional argument or keyword argument 'confidence' instead.
#   print(st.t.interval(alpha=0.90, df=len(datos)-1, loc=np.mean(datos), scale=st.sem(datos)))

# %% [markdown]
#     2. Interpretación de los resultados.
#         2.1. Ahora interpreta los resultados obtenidos de los diferentes estadísticos estudiados haciendo hincapié en aspectos interesantes de tus datos y explica lo mejor posible la naturaleza de los mismos.

# %% [markdown]
# El Volumen de ventas se ve muy afectado porque hay muy pocas compras con mucha cantidad de kilos, lo que nos modifica la media sustancialmente; también afecta al intervalo de confianza.

# %% [markdown]
# El precio sigue una distribución casi normal, ligeramente sesgado a la derecha pero con muy pococs valores extremos, que afectan poco a la media y al intervalo de confianza.
