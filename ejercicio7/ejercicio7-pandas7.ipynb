# %% [markdown]
# Pair Programming Pandas VII
# En los ejercicios de hoy pondremos en práctica los apply, y nos crearemos algunas funciones que nos van a permitir limpiar un poco los datos, para que podamos extraer conclusiones de una forma más sencilla. Para ellos seguiremos trabajando con mismos csv que en el pair anterior, el de los empleados que unimos en el pair de unión de datasets y el de los tickets de todos los años. Para ello, lo primero que tendremos que hacer es cargar estos dos csv.
# Como hemos dicho hasta ahora, hemos estado explorando los datos, y puede que ya nos hayamos dado cuenta de que hay columnas de que están un poco "sucias". Hoy limpiaremos esas columnas para poder extraer conclusiones más eficaces.
# Manos a la obra 💪🏽! Los objetivos de la clase de hoy son:
#
#     1. Cread una columna nueva y una función que nos de el mes en el que se solicitó el servicio. Tened en cuenta que todas las filas tienen la misma estructura. A la hora de escribir la función debemos tener en cuenta que puede que no haya la información de mes en la columna de la fecha. En ese caso devolved un nulo (NaN).
# 📌 Nota La fecha tendrá que ir formato de string como "Enero", "Febrero", etc.
# 💡 Pista 💡Podréis usar regex, pero no es estrictamente necesario.

# %%
import pandas as pd
import numpy as np
import re
import datetime as dt

# %%
df_tickets = pd.read_csv("datos/tickets_years.csv", index_col = 0)
df_tickets.head()
# Out:
#            id_ticket       fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453  2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060  2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995  2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006  2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120  2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción   año     semestre
# 0           5.0  2016  2º semestre
# 1           5.0  2016  1º semestre
# 2           5.0  2016  1º semestre
# 3           5.0  2016  1º semestre
# 4           5.0  2016  1º semestre

# %%
def sacar_mes(mes):
    try:
        return mes.strftime("%B")
    except: 
        return np.nan

# %%
df_tickets["fecha"]= df_tickets["fecha"].apply(pd.to_datetime)

# %%
df_tickets["mes"]= df_tickets["fecha"].apply(sacar_mes)

# %%
df_tickets.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción   año     semestre    mes
# 0           5.0  2016  2º semestre   July
# 1           5.0  2016  1º semestre    May
# 2           5.0  2016  1º semestre   June
# 3           5.0  2016  1º semestre  April
# 4           5.0  2016  1º semestre   June

# %%
diccionario_mes = {"January" : "Enero", "February": "Febrero", "March": "Marzo", "April": "Abril", "May": "Mayo", "June": "Junio", "July": "Julio", "August": "Agosto", "September": "Septiembre", "October": "Octubre", "November": "Noviembre", "December": "Diciembre"}

# %%
diccionario_mes["April"]
# Out:
# 'Abril'

# %%
def traducir_fecha (columna):
    try:
        return diccionario_mes[columna]
    except: 
        return np.nan

# %%
df_tickets["mes"]= df_tickets["mes"].apply(traducir_fecha)
df_tickets.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción   año     semestre    mes
# 0           5.0  2016  2º semestre  Julio
# 1           5.0  2016  1º semestre   Mayo
# 2           5.0  2016  1º semestre  Junio
# 3           5.0  2016  1º semestre  Abril
# 4           5.0  2016  1º semestre  Junio

# %% [markdown]
#     2. En la tabla de empleados, tenemos los nombres y los apellidos de los empleados, pero en columnas separadas. En los ejercicios de pair de la lección del groupby vimos que si quisieramos agrupar por los nombres, esto se nos puede complicar. Ahora nos piden que creemos una columna donde tengamos el nombre y el apellido juntos.
# 📌 NOTA La columna nueva debe tener el nombre y apellido con la primera letra en mayúsculas, por ejemplo "Jesús Villa".
# 📌 NOTA Una vez hallamos creado la columna nueva, eliminad las columnas de nombre y apellido originales.

# %%
df_empleados = pd.read_csv("datos/empleo.csv", index_col = 0)
df_empleados.head()
# Out:
#   turno  id_empleado    apellido    nombre id_puesto  \
# 0     A            6       VILLA     JESUS  50-32200
# 1   NaN           60        DIAZ  PATRICIA  50-32200
# 2     B            2      DUARTE   ANTONIO  50-32200
# 3   NaN           24  VILLANUEVA     JESUS  50-32200
# 4   NaN           98    GALLEGOS  PATRICIA  50-32200
#
#                              email                   puesto  \
# 0        jesus.villa@tractchun.com  Comprador de Materiales
# 1      patricia.diaz@tractchun.com  Comprador de Materiales
# 2     antonio.duarte@tractchun.com  Comprador de Materiales
# 3   jesus.villanueva@tractchun.com  Comprador de Materiales
# 4  patricia.gallegos@tractchun.com  Comprador de Materiales
#
#             departamento     tipo_puesto
# 0  CONTROL DE PRODUCCION  Administrativo
# 1  CONTROL DE PRODUCCION  Administrativo
# 2  CONTROL DE PRODUCCION  Administrativo
# 3  CONTROL DE PRODUCCION  Administrativo
# 4  CONTROL DE PRODUCCION  Administrativo

# %%
def juntar_nombre (nombre, apellido):
    nombre= nombre.title()
    apellido= apellido.title()
    nombre_completo = nombre + " " + apellido
    return nombre_completo

# %%
df_empleados["nombre_completo"] = df_empleados.apply(lambda dataframe: juntar_nombre(dataframe["nombre"], dataframe["apellido"]), axis = 1)

# %%
df_empleados.head()
# Out:
#   turno  id_empleado    apellido    nombre id_puesto  \
# 0     A            6       VILLA     JESUS  50-32200
# 1   NaN           60        DIAZ  PATRICIA  50-32200
# 2     B            2      DUARTE   ANTONIO  50-32200
# 3   NaN           24  VILLANUEVA     JESUS  50-32200
# 4   NaN           98    GALLEGOS  PATRICIA  50-32200
#
#                              email                   puesto  \
# 0        jesus.villa@tractchun.com  Comprador de Materiales
# 1      patricia.diaz@tractchun.com  Comprador de Materiales
# 2     antonio.duarte@tractchun.com  Comprador de Materiales
# 3   jesus.villanueva@tractchun.com  Comprador de Materiales
# 4  patricia.gallegos@tractchun.com  Comprador de Materiales
#
#             departamento     tipo_puesto    nombre_completo
# 0  CONTROL DE PRODUCCION  Administrativo        Jesus Villa
# 1  CONTROL DE PRODUCCION  Administrativo      Patricia Diaz
# 2  CONTROL DE PRODUCCION  Administrativo     Antonio Duarte
# 3  CONTROL DE PRODUCCION  Administrativo   Jesus Villanueva
# 4  CONTROL DE PRODUCCION  Administrativo  Patricia Gallegos

# %%
df_empleados.drop(["apellido", "nombre"], axis = 1, inplace= True)

# %%
df_empleados.head()
# Out:
#   turno  id_empleado id_puesto                            email  \
# 0     A            6  50-32200        jesus.villa@tractchun.com
# 1   NaN           60  50-32200      patricia.diaz@tractchun.com
# 2     B            2  50-32200     antonio.duarte@tractchun.com
# 3   NaN           24  50-32200   jesus.villanueva@tractchun.com
# 4   NaN           98  50-32200  patricia.gallegos@tractchun.com
#
#                     puesto           departamento     tipo_puesto  \
# 0  Comprador de Materiales  CONTROL DE PRODUCCION  Administrativo
# 1  Comprador de Materiales  CONTROL DE PRODUCCION  Administrativo
# 2  Comprador de Materiales  CONTROL DE PRODUCCION  Administrativo
# 3  Comprador de Materiales  CONTROL DE PRODUCCION  Administrativo
# 4  Comprador de Materiales  CONTROL DE PRODUCCION  Administrativo
#
#      nombre_completo
# 0        Jesus Villa
# 1      Patricia Diaz
# 2     Antonio Duarte
# 3   Jesus Villanueva
# 4  Patricia Gallegos

# %% [markdown]
#
#     3. En el pair programming desde a dirección nos pedían que agruparamos los datos en base a la columna de "categoría", puede que en aquel momento nos dieramos cuenta que había varías categorías que eran igual (en concreto "Acceso Login") pero que en algunos casos tenía unos símbolos raros (&, %, -). Es el momento de limpiar esta columna. El objetivo, reemplazar todos estos símbolos raros por "/", para conseguir homogeneizar los valores de esta columna. Para ellos deberemos crear una función.

# %%
df_tickets["categoría"].unique()
# Out:
# array(['Acceso&%Login', 'Sistema', 'Software', 'Hardware', nan,
#        'Acceso%&Login', 'Acceso-&Login', 'Acceso99Login', 'Acceso/Login'],
#       dtype=object)

# %%
patron = "Acces.*"
patron_dos = "Acceso/Login"

# %%
def cambiar_categoria (patron1, patron2, columna_a_cambiar):
    try:
        cambiado = re.sub(patron1, patron2, columna_a_cambiar)
        return cambiado
    except:
        return np.nan

# %%
df_tickets["categoria"] = df_tickets.apply(lambda df: cambiar_categoria (patron, patron_dos, df["categoría"]), axis = 1)
df_tickets.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción   año     semestre    mes     categoria
# 0           5.0  2016  2º semestre  Julio  Acceso/Login
# 1           5.0  2016  1º semestre   Mayo  Acceso/Login
# 2           5.0  2016  1º semestre  Junio       Sistema
# 3           5.0  2016  1º semestre  Abril       Sistema
# 4           5.0  2016  1º semestre  Junio      Software

# %% [markdown]
#     4. Una vez que hayáis terminado eliminad las columnas originales conservando las nuevas.

# %%
df_tickets.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción   año     semestre    mes     categoria
# 0           5.0  2016  2º semestre  Julio  Acceso/Login
# 1           5.0  2016  1º semestre   Mayo  Acceso/Login
# 2           5.0  2016  1º semestre  Junio       Sistema
# 3           5.0  2016  1º semestre  Abril       Sistema
# 4           5.0  2016  1º semestre  Junio      Software

# %%
df_tickets.drop(["categoría"], axis = 1, inplace= True)

# %% [markdown]
#     5. Guardad el dataframe en un csv que usaremos más adelante

# %%
df_tickets.to_csv("datos/tickets_years2")
df_empleados.to_csv("datos/empleo2")
